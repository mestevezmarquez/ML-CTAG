# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# # Parte 1

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame(columns = ["col1","col2"])
df
# Out:
# Empty DataFrame
# Columns: [col1, col2]
# Index: []

# %%
df = pd.DataFrame(columns = ["col1","col2"], index=["a","b","c"])
df
# Out:
#   col1 col2
# a  NaN  NaN
# b  NaN  NaN
# c  NaN  NaN

# %%
df['col1']
# Out:
# a    NaN
# b    NaN
# c    NaN
# Name: col1, dtype: object

# %%
df["col1"]=[50,60,30]
df["col2"] = ["a",[1,2],{"key":"value"}]
df
# Out:
#    col1              col2
# a    50                 a
# b    60            [1, 2]
# c    30  {'key': 'value'}

# %%
df = pd.DataFrame({"Números":range(2), "Letras":["a","b"]}, index=["indice1","indice2"])
df
# Out:
#          Números Letras
# indice1        0      a
# indice2        1      b

# %%
df.columns
# Out:
# Index(['Números', 'Letras'], dtype='object')

# %%
rango = pd.date_range("2020-01-31",periods=5, freq="3D")
rango
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-03', '2020-02-06', '2020-02-09',
#                '2020-02-12'],
#               dtype='datetime64[ns]', freq='3D')

# %%
pd.DataFrame({"Fecha":rango})
# Out:
#        Fecha
# 0 2020-01-31
# 1 2020-02-03
# 2 2020-02-06
# 3 2020-02-09
# 4 2020-02-12

# %%
df = pd.read_csv("iris.csv")
df#.head() #Muestra las primeras 5 filas del dataframe
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df = pd.read_excel("iris.xlsx", sheet_name = 0)
df
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 0             5.1            3.5            1.4            0.2     Iris-setosa
# 1             4.9            3.0            1.4            0.2     Iris-setosa
# 2             4.7            3.2            1.3            0.2     Iris-setosa
# 3             4.6            3.1            1.5            0.2     Iris-setosa
# 4             5.0            3.6            1.4            0.2     Iris-setosa
# ..            ...            ...            ...            ...             ...
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head(1) #Solo queremos mostrar una fila
# Out:
#    Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo        Clase
# 0           5.1            3.5            1.4            0.2  Iris-setosa

# %%
df.head(15)
# Out:
#     Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo        Clase
# 0            5.1            3.5            1.4            0.2  Iris-setosa
# 1            4.9            3.0            1.4            0.2  Iris-setosa
# 2            4.7            3.2            1.3            0.2  Iris-setosa
# 3            4.6            3.1            1.5            0.2  Iris-setosa
# 4            5.0            3.6            1.4            0.2  Iris-setosa
# 5            5.4            3.9            1.7            0.4  Iris-setosa
# 6            4.6            3.4            1.4            0.3  Iris-setosa
# 7            5.0            3.4            1.5            0.2  Iris-setosa
# 8            4.4            2.9            1.4            0.2  Iris-setosa
# 9            4.9            3.1            1.5            0.1  Iris-setosa
# 10           5.4            3.7            1.5            0.2  Iris-setosa
# ...

# %%
df.tail() #Muestra las ultimas 5 filas del dataframe
# Out:
#      Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo           Clase
# 145           6.7            3.0            5.2            2.3  Iris-virginica
# 146           6.3            2.5            5.0            1.9  Iris-virginica
# 147           6.5            3.0            5.2            2.0  Iris-virginica
# 148           6.2            3.4            5.4            2.3  Iris-virginica
# 149           5.9            3.0            5.1            1.8  Iris-virginica

# %%
df.shape #Muestra el tamaño del dataframe
# Out:
# (150, 5)

# %%
len(df) #Número de filas del dataframe
# Out:
# 150

# %%
df.index #Devuelve los indices del dataframe
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns #Duevuelve los nombres de las columnas
# Out:
# Index(['Largo Sepalo', ' Ancho Sepalo', ' Largo Petalo', ' Ancho Petalo',
#        ' Clase'],
#       dtype='object')

# %%
df.describe() #Devuelve una descripción estadistica del dataframe
# Out:
#        Largo Sepalo   Ancho Sepalo   Largo Petalo   Ancho Petalo
# count    150.000000     150.000000     150.000000     150.000000
# mean       5.843333       3.054000       3.758667       1.198667
# std        0.828066       0.433594       1.764420       0.763161
# min        4.300000       2.000000       1.000000       0.100000
# 25%        5.100000       2.800000       1.600000       0.300000
# 50%        5.800000       3.000000       4.350000       1.300000
# 75%        6.400000       3.300000       5.100000       1.800000
# max        7.900000       4.400000       6.900000       2.500000

# %%
df.info() #Devuelve información del tipo de cada columna, memoria que utliza el dataframe, número de columnas y tamaño del índice
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Largo Sepalo   150 non-null    float64
#  1    Ancho Sepalo  150 non-null    float64
#  2    Largo Petalo  150 non-null    float64
#  3    Ancho Petalo  150 non-null    float64
#  4    Clase         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.count() #Cuenta el número de elementos que no son NaN de cada columna
# Out:
# Largo Sepalo     150
#  Ancho Sepalo    150
#  Largo Petalo    150
#  Ancho Petalo    150
#  Clase           150
# dtype: int64

# %%
df.sum() #Devuelve la suma de cada columna de sus elementos (Solo aplica para columnas númericas).
         #También se puede utilizaz para cada columna
# Out:
# Largo Sepalo                                                 876.5
#  Ancho Sepalo                                                458.1
#  Largo Petalo                                                563.8
#  Ancho Petalo                                                179.8
#  Clase           Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
df.sum(axis=1) #Devuelve la suma horizantal de cada fila
# Out:
# 0      10.2
# 1       9.5
# 2       9.4
# 3       9.4
# 4      10.2
#        ...
# 145    17.2
# 146    15.7
# 147    16.7
# 148    17.3
# 149    15.8
# Length: 150, dtype: float64

# %%
df = pd.read_csv("iris.csv")
#df1 = df[['Largo Sepalo', 'Ancho Sepalo']]
#df1
#df.cumsum(axis=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
dfcumsum = df.cumsum(axis=0) #Muestra la suma acomulativa 
dfcumsum
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# 0             5.1           3.5           1.4           0.2
# 1            10.0           6.5           2.8           0.4
# 2            14.7           9.7           4.1           0.6
# 3            19.3          12.8           5.6           0.8
# 4            24.3          16.4           7.0           1.0
# ..            ...           ...           ...           ...
# 145         851.6         446.2         543.1         171.8
# 146         857.9         448.7         548.1         173.7
# 147         864.4         451.7         553.3         175.7
# 148         870.6         455.1         558.7         178.0
# 149         876.5         458.1         563.8         179.8
#
#                                                  Clase
# 0                                          Iris-setosa
# 1                               Iris-setosaIris-setosa
# 2                    Iris-setosaIris-setosaIris-setosa
# ...

# %%
df.head(1)
# Out:
#    Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# 0           5.1           3.5           1.4           0.2  Iris-setosa

# %%
dfcumsum["Largo Sepalo"]
# Out:
# 0        5.1
# 1       10.0
# 2       14.7
# 3       19.3
# 4       24.3
#        ...
# 145    851.6
# 146    857.9
# 147    864.4
# 148    870.6
# 149    876.5
# Name: Largo Sepalo, Length: 150, dtype: float64

# %%
df["nueva columna"] = dfcumsum["Largo Sepalo"] #Creo una nueva columna y le asigno los valores de la suma acumulada de la columna largo sepalo
df
# Out:
#      Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo           Clase  \
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
#      nueva columna
# 0              5.1
# ...

# %%
print(df.min()) #Minimo de cada columna
print("****")
print(df.max()) #Máximo de cada columna
# Out:
# Largo Sepalo             4.3
# Ancho Sepalo             2.0
# Largo Petalo             1.0
# Ancho Petalo             0.1
# Clase            Iris-setosa
# nueva columna            5.1
# dtype: object
# ****
# Largo Sepalo                7.9
# Ancho Sepalo                4.4
# Largo Petalo                6.9
# Ancho Petalo                2.5
# Clase            Iris-virginica
# nueva columna             876.5
# dtype: object

# %%
df.mean() #Promedio de cada columna
# Out:
# Largo Sepalo       5.843333
# Ancho Sepalo       3.054000
# Largo Petalo       3.758667
# Ancho Petalo       1.198667
# nueva columna    415.560667
# dtype: float64

# %%
df.median() #mediana de cada columna
# Out:
# Largo Sepalo       5.80
# Ancho Sepalo       3.00
# Largo Petalo       4.35
# Ancho Petalo       1.30
# nueva columna    403.90
# dtype: float64

# %%
df.iloc[1][1] #Selección de un elemento por coordenadas
# Out:
# 3.0

# %%
df.iloc[1,1] #Selección de un elemento por coordenadas
# Out:
# 3.0

# %%
df.iloc[50:60,2:4]
# Out:
#      Largo Petalo   Ancho Petalo
# 50            4.7            1.4
# 51            4.5            1.5
# 52            4.9            1.5
# 53            4.0            1.3
# 54            4.6            1.5
# 55            4.5            1.3
# 56            4.7            1.6
# 57            3.3            1.0
# 58            4.6            1.3
# 59            3.9            1.4

# %%
df.index = ["indice"+str(i) for i in range(150)]
df
# Out:
#            Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo  \
# indice0             5.1           3.5           1.4           0.2
# indice1             4.9           3.0           1.4           0.2
# indice2             4.7           3.2           1.3           0.2
# indice3             4.6           3.1           1.5           0.2
# indice4             5.0           3.6           1.4           0.2
# ...                 ...           ...           ...           ...
# indice145           6.7           3.0           5.2           2.3
# indice146           6.3           2.5           5.0           1.9
# indice147           6.5           3.0           5.2           2.0
# indice148           6.2           3.4           5.4           2.3
# indice149           5.9           3.0           5.1           1.8
#
#                     Clase
# indice0       Iris-setosa
# indice1       Iris-setosa
# indice2       Iris-setosa
# indice3       Iris-setosa
# indice4       Iris-setosa
# ...

# %%
df["Largo Sepalo"]["indice2"] #Selección de un elemento para una columna
# Out:
# 4.7

# %%
df.iloc[2,0]
# Out:
# 4.7

# %%
df.loc["indice0","Largo Sepalo"] #Selección de un elemento por índice y nombre de columna
# Out:
# 5.1

# %%
df.iloc[0,0]
# Out:
# 5.1

# %%
df.head(10)
# Out:
#          Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# indice0           5.1           3.5           1.4           0.2  Iris-setosa
# indice1           4.9           3.0           1.4           0.2  Iris-setosa
# indice2           4.7           3.2           1.3           0.2  Iris-setosa
# indice3           4.6           3.1           1.5           0.2  Iris-setosa
# indice4           5.0           3.6           1.4           0.2  Iris-setosa
# indice5           5.4           3.9           1.7           0.4  Iris-setosa
# indice6           4.6           3.4           1.4           0.3  Iris-setosa
# indice7           5.0           3.4           1.5           0.2  Iris-setosa
# indice8           4.4           2.9           1.4           0.2  Iris-setosa
# indice9           4.9           3.1           1.5           0.1  Iris-setosa

# %%
df["Largo Sepalo"]>=5
# Out:
# indice0       True
# indice1      False
# indice2      False
# indice3      False
# indice4       True
#              ...
# indice145     True
# indice146     True
# indice147     True
# indice148     True
# indice149     True
# Name: Largo Sepalo, Length: 150, dtype: bool

# %%
df.loc[df["Largo Sepalo"]>=5, "Largo Sepalo"] = "Hola mundo" #Todos los que sean mayor a 5 en la columna Largo Sepalo igual a hola mundo 
df.head()
# Out:
#         Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# indice0   Hola mundo           3.5           1.4           0.2  Iris-setosa
# indice1          4.9           3.0           1.4           0.2  Iris-setosa
# indice2          4.7           3.2           1.3           0.2  Iris-setosa
# indice3          4.6           3.1           1.5           0.2  Iris-setosa
# indice4   Hola mundo           3.6           1.4           0.2  Iris-setosa

# %%
df.iat[0,2]= 99 #Asignar un nuevo valor a un elemento 
df.head(3)
# Out:
#         Largo Sepalo  Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# indice0   Hola mundo           3.5          99.0           0.2  Iris-setosa
# indice1          4.9           3.0           1.4           0.2  Iris-setosa
# indice2          4.7           3.2           1.3           0.2  Iris-setosa

# %%
df["Ancho Sepalo"] = df["Clase"]
lista = [i for i in range(150)]
df["Largo Petalo"] = lista #Cambiar el valor de toda una columna
df.head(9)
# Out:
#         Largo Sepalo Ancho Sepalo  Largo Petalo  Ancho Petalo        Clase
# indice0   Hola mundo  Iris-setosa             0           0.2  Iris-setosa
# indice1          4.9  Iris-setosa             1           0.2  Iris-setosa
# indice2          4.7  Iris-setosa             2           0.2  Iris-setosa
# indice3          4.6  Iris-setosa             3           0.2  Iris-setosa
# indice4   Hola mundo  Iris-setosa             4           0.2  Iris-setosa
# indice5   Hola mundo  Iris-setosa             5           0.4  Iris-setosa
# indice6          4.6  Iris-setosa             6           0.3  Iris-setosa
# indice7   Hola mundo  Iris-setosa             7           0.2  Iris-setosa
# indice8          4.4  Iris-setosa             8           0.2  Iris-setosa

# %%
df.columns  = ["a","b","c","d","e"]

# %%
df.head(3)
# Out:
#                   a            b  c    d            e
# indice0  Hola mundo  Iris-setosa  0  0.2  Iris-setosa
# indice1         4.9  Iris-setosa  1  0.2  Iris-setosa
# indice2         4.7  Iris-setosa  2  0.2  Iris-setosa

# %%
df = df.rename(columns={"e":"A"})
df
# Out:
#                     a               b    c    d               A
# indice0    Hola mundo     Iris-setosa    0  0.2     Iris-setosa
# indice1           4.9     Iris-setosa    1  0.2     Iris-setosa
# indice2           4.7     Iris-setosa    2  0.2     Iris-setosa
# indice3           4.6     Iris-setosa    3  0.2     Iris-setosa
# indice4    Hola mundo     Iris-setosa    4  0.2     Iris-setosa
# ...               ...             ...  ...  ...             ...
# indice145  Hola mundo  Iris-virginica  145  2.3  Iris-virginica
# indice146  Hola mundo  Iris-virginica  146  1.9  Iris-virginica
# indice147  Hola mundo  Iris-virginica  147  2.0  Iris-virginica
# indice148  Hola mundo  Iris-virginica  148  2.3  Iris-virginica
# indice149  Hola mundo  Iris-virginica  149  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'A', 'f'], dtype='object')

# %%
df2 = df.head() #Crear un nuevo dataframe a partir de otro dataframe
df2
# Out:
#                   a            b  c    d            A
# indice0  Hola mundo  Iris-setosa  0  0.2  Iris-setosa
# indice1         4.9  Iris-setosa  1  0.2  Iris-setosa
# indice2         4.7  Iris-setosa  2  0.2  Iris-setosa
# indice3         4.6  Iris-setosa  3  0.2  Iris-setosa
# indice4  Hola mundo  Iris-setosa  4  0.2  Iris-setosa

# %%
df2.index = ["a","b","c","d","e"] #Cambiar los valores de los indices
df2
# Out:
#             a            b  c    d            A
# a  Hola mundo  Iris-setosa  0  0.2  Iris-setosa
# b         4.9  Iris-setosa  1  0.2  Iris-setosa
# c         4.7  Iris-setosa  2  0.2  Iris-setosa
# d         4.6  Iris-setosa  3  0.2  Iris-setosa
# e  Hola mundo  Iris-setosa  4  0.2  Iris-setosa

# %%
df2 = df2.rename(columns={"c":100})
df2
# Out:
#             a            b  100    d            A
# a  Hola mundo  Iris-setosa    0  0.2  Iris-setosa
# b         4.9  Iris-setosa    1  0.2  Iris-setosa
# c         4.7  Iris-setosa    2  0.2  Iris-setosa
# d         4.6  Iris-setosa    3  0.2  Iris-setosa
# e  Hola mundo  Iris-setosa    4  0.2  Iris-setosa

# %%
df2.loc['d',100]
# Out:
# 3

# %%
df
# Out:
#                     a               b    c    d               A
# indice32   Hola mundo     Iris-setosa   32  0.1     Iris-setosa
# indice13          4.3     Iris-setosa   13  0.1     Iris-setosa
# indice37          4.9     Iris-setosa   37  0.1     Iris-setosa
# indice9           4.9     Iris-setosa    9  0.1     Iris-setosa
# indice12          4.8     Iris-setosa   12  0.1     Iris-setosa
# ...               ...             ...  ...  ...             ...
# indice140  Hola mundo  Iris-virginica  140  2.4  Iris-virginica
# indice114  Hola mundo  Iris-virginica  114  2.4  Iris-virginica
# indice100  Hola mundo  Iris-virginica  100  2.5  Iris-virginica
# indice144  Hola mundo  Iris-virginica  144  2.5  Iris-virginica
# indice109  Hola mundo  Iris-virginica  109  2.5  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values("c") #ordena los valores
# Out:
#                     a               b    c    d               A
# indice0    Hola mundo     Iris-setosa    0  0.2     Iris-setosa
# indice1           4.9     Iris-setosa    1  0.2     Iris-setosa
# indice2           4.7     Iris-setosa    2  0.2     Iris-setosa
# indice3           4.6     Iris-setosa    3  0.2     Iris-setosa
# indice4    Hola mundo     Iris-setosa    4  0.2     Iris-setosa
# ...               ...             ...  ...  ...             ...
# indice145  Hola mundo  Iris-virginica  145  2.3  Iris-virginica
# indice146  Hola mundo  Iris-virginica  146  1.9  Iris-virginica
# indice147  Hola mundo  Iris-virginica  147  2.0  Iris-virginica
# indice148  Hola mundo  Iris-virginica  148  2.3  Iris-virginica
# indice149  Hola mundo  Iris-virginica  149  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df = df.sort_values("c", ascending=False) #ordena los valores

# %%
df
# Out:
#                     a               b    c    d               A
# indice149  Hola mundo  Iris-virginica  149  1.8  Iris-virginica
# indice148  Hola mundo  Iris-virginica  148  2.3  Iris-virginica
# indice147  Hola mundo  Iris-virginica  147  2.0  Iris-virginica
# indice146  Hola mundo  Iris-virginica  146  1.9  Iris-virginica
# indice145  Hola mundo  Iris-virginica  145  2.3  Iris-virginica
# ...               ...             ...  ...  ...             ...
# indice4    Hola mundo     Iris-setosa    4  0.2     Iris-setosa
# indice3           4.6     Iris-setosa    3  0.2     Iris-setosa
# indice2           4.7     Iris-setosa    2  0.2     Iris-setosa
# indice1           4.9     Iris-setosa    1  0.2     Iris-setosa
# indice0    Hola mundo     Iris-setosa    0  0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %%
df2 = df.reset_index(drop=True)
df2
# Out:
#               a               b    c    d               A
# 0    Hola mundo  Iris-virginica  149  1.8  Iris-virginica
# 1    Hola mundo  Iris-virginica  148  2.3  Iris-virginica
# 2    Hola mundo  Iris-virginica  147  2.0  Iris-virginica
# 3    Hola mundo  Iris-virginica  146  1.9  Iris-virginica
# 4    Hola mundo  Iris-virginica  145  2.3  Iris-virginica
# ..          ...             ...  ...  ...             ...
# 145  Hola mundo     Iris-setosa    4  0.2     Iris-setosa
# 146         4.6     Iris-setosa    3  0.2     Iris-setosa
# 147         4.7     Iris-setosa    2  0.2     Iris-setosa
# 148         4.9     Iris-setosa    1  0.2     Iris-setosa
# 149  Hola mundo     Iris-setosa    0  0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#               a               b    c    d               A
# 0    Hola mundo  Iris-virginica  149  1.8  Iris-virginica
# 1    Hola mundo  Iris-virginica  148  2.3  Iris-virginica
# 2    Hola mundo  Iris-virginica  147  2.0  Iris-virginica
# 3    Hola mundo  Iris-virginica  146  1.9  Iris-virginica
# 4    Hola mundo  Iris-virginica  145  2.3  Iris-virginica
# ..          ...             ...  ...  ...             ...
# 145  Hola mundo     Iris-setosa    4  0.2     Iris-setosa
# 146         4.6     Iris-setosa    3  0.2     Iris-setosa
# 147         4.7     Iris-setosa    2  0.2     Iris-setosa
# 148         4.9     Iris-setosa    1  0.2     Iris-setosa
# 149  Hola mundo     Iris-setosa    0  0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %%
df.sort_values("d", ascending=False, inplace=True)

# %%
df
# Out:
#               a               b    c    d               A
# 40   Hola mundo  Iris-virginica  109  2.5  Iris-virginica
# 5    Hola mundo  Iris-virginica  144  2.5  Iris-virginica
# 49   Hola mundo  Iris-virginica  100  2.5  Iris-virginica
# 35   Hola mundo  Iris-virginica  114  2.4  Iris-virginica
# 9    Hola mundo  Iris-virginica  140  2.4  Iris-virginica
# ..          ...             ...  ...  ...             ...
# 137         4.8     Iris-setosa   12  0.1     Iris-setosa
# 140         4.9     Iris-setosa    9  0.1     Iris-setosa
# 112         4.9     Iris-setosa   37  0.1     Iris-setosa
# 136         4.3     Iris-setosa   13  0.1     Iris-setosa
# 117  Hola mundo     Iris-setosa   32  0.1     Iris-setosa
#
# [150 rows x 5 columns]

# %%
df.sort_values("f", ascending=False, inplace=True) 
df
# Out:
#        a    b    c    d               A      f    g               z
# 38   0.0  3.0  5.1  1.8  Iris-virginica  876.5  149  Iris-virginica
# 6    0.0  3.4  5.4  2.3  Iris-virginica  870.6  148  Iris-virginica
# 27   0.0  3.0  5.2  2.0  Iris-virginica  864.4  147  Iris-virginica
# 33   0.0  2.5  5.0  1.9  Iris-virginica  857.9  146  Iris-virginica
# 8    0.0  3.0  5.2  2.3  Iris-virginica  851.6  145  Iris-virginica
# ..   ...  ...  ...  ...             ...    ...  ...             ...
# 127  5.0  3.6  1.4  0.2     Iris-setosa   24.3    4     Iris-setosa
# 128  4.6  3.1  1.5  0.2     Iris-setosa   19.3    3     Iris-setosa
# 129  4.7  3.2  1.3  0.2     Iris-setosa   14.7    2     Iris-setosa
# 126  4.9  3.0  1.4  0.2     Iris-setosa   10.0    1     Iris-setosa
# 139  0.0  3.5  1.4  0.2     Iris-setosa    5.1    0     Iris-setosa
#
# [150 rows x 8 columns]

# %%
df = df.sort_values("f", ascending=True) #ordena los valores
df
# Out:
#      index           a               b    c    d               A      f
# 11     139  Hola mundo     Iris-setosa    0  0.2     Iris-setosa    5.1
# 32     126         4.9     Iris-setosa    1  0.2     Iris-setosa   10.0
# 20     129         4.7     Iris-setosa    2  0.2     Iris-setosa   14.7
# 25     128         4.6     Iris-setosa    3  0.2     Iris-setosa   19.3
# 33     127  Hola mundo     Iris-setosa    4  0.2     Iris-setosa   24.3
# ..     ...         ...             ...  ...  ...             ...    ...
# 140      8  Hola mundo  Iris-virginica  145  2.3  Iris-virginica  851.6
# 116     33  Hola mundo  Iris-virginica  146  1.9  Iris-virginica  857.9
# 122     27  Hola mundo  Iris-virginica  147  2.0  Iris-virginica  864.4
# 142      6  Hola mundo  Iris-virginica  148  2.3  Iris-virginica  870.6
# 111     38  Hola mundo  Iris-virginica  149  1.8  Iris-virginica  876.5
#
# [150 rows x 7 columns]

# %%
df = df.reset_index(drop=False)
df
# Out:
#      index    a    b    c    d               A      f    g               z
# 0       38  0.0  3.0  5.1  1.8  Iris-virginica  876.5  149  Iris-virginica
# 1        6  0.0  3.4  5.4  2.3  Iris-virginica  870.6  148  Iris-virginica
# 2       27  0.0  3.0  5.2  2.0  Iris-virginica  864.4  147  Iris-virginica
# 3       33  0.0  2.5  5.0  1.9  Iris-virginica  857.9  146  Iris-virginica
# 4        8  0.0  3.0  5.2  2.3  Iris-virginica  851.6  145  Iris-virginica
# ..     ...  ...  ...  ...  ...             ...    ...  ...             ...
# 145    127  5.0  3.6  1.4  0.2     Iris-setosa   24.3    4     Iris-setosa
# 146    128  4.6  3.1  1.5  0.2     Iris-setosa   19.3    3     Iris-setosa
# 147    129  4.7  3.2  1.3  0.2     Iris-setosa   14.7    2     Iris-setosa
# 148    126  4.9  3.0  1.4  0.2     Iris-setosa   10.0    1     Iris-setosa
# 149    139  0.0  3.5  1.4  0.2     Iris-setosa    5.1    0     Iris-setosa
#
# [150 rows x 9 columns]

# %%
df.reset_index(inplace=True, drop=True) #reiniciar el indice 
df
# Out:
#      index    a    b    c    d               A      f    g               z
# 0       38  0.0  3.0  5.1  1.8  Iris-virginica  876.5  149  Iris-virginica
# 1        6  0.0  3.4  5.4  2.3  Iris-virginica  870.6  148  Iris-virginica
# 2       27  0.0  3.0  5.2  2.0  Iris-virginica  864.4  147  Iris-virginica
# 3       33  0.0  2.5  5.0  1.9  Iris-virginica  857.9  146  Iris-virginica
# 4        8  0.0  3.0  5.2  2.3  Iris-virginica  851.6  145  Iris-virginica
# ..     ...  ...  ...  ...  ...             ...    ...  ...             ...
# 145    127  5.0  3.6  1.4  0.2     Iris-setosa   24.3    4     Iris-setosa
# 146    128  4.6  3.1  1.5  0.2     Iris-setosa   19.3    3     Iris-setosa
# 147    129  4.7  3.2  1.3  0.2     Iris-setosa   14.7    2     Iris-setosa
# 148    126  4.9  3.0  1.4  0.2     Iris-setosa   10.0    1     Iris-setosa
# 149    139  0.0  3.5  1.4  0.2     Iris-setosa    5.1    0     Iris-setosa
#
# [150 rows x 9 columns]

# %%
#del df["A"] #eliminar una columna
df.head()
# Out:
#              a    c    d               A
# 40  Hola mundo  109  2.5  Iris-virginica
# 5   Hola mundo  144  2.5  Iris-virginica
# 49  Hola mundo  100  2.5  Iris-virginica
# 35  Hola mundo  114  2.4  Iris-virginica
# 9   Hola mundo  140  2.4  Iris-virginica

# %%
df.drop([40,5], axis=0, inplace=True) #Eliminar la columna d ¡Ojo! No se asigno a df, por lo que df permanece igual

# %%
df
# Out:
#        d               A
# 49   2.5  Iris-virginica
# 35   2.4  Iris-virginica
# 9    2.4  Iris-virginica
# 13   2.4  Iris-virginica
# 14   2.3  Iris-virginica
# ..   ...             ...
# 137  0.1     Iris-setosa
# 140  0.1     Iris-setosa
# 112  0.1     Iris-setosa
# 136  0.1     Iris-setosa
# 117  0.1     Iris-setosa
#
# [148 rows x 2 columns]

# %%
df.drop("f", inplace=True,axis=1) #columna axis =1 
df
# Out:
#        d
# 11   0.2
# 32   0.2
# 20   0.2
# 25   0.2
# 33   0.2
# ..   ...
# 140  2.3
# 116  1.9
# 122  2.0
# 142  2.3
# 111  1.8
#
# [150 rows x 1 columns]

# %%
df.drop(49,axis=0, inplace=True)
df
# Out:
#        d               A
# 35   2.4  Iris-virginica
# 9    2.4  Iris-virginica
# 13   2.4  Iris-virginica
# 14   2.3  Iris-virginica
# 31   2.3  Iris-virginica
# ..   ...             ...
# 137  0.1     Iris-setosa
# 140  0.1     Iris-setosa
# 112  0.1     Iris-setosa
# 136  0.1     Iris-setosa
# 117  0.1     Iris-setosa
#
# [146 rows x 2 columns]

# %%
del df["A"]

# %%
df
# Out:
#        d
# 35   2.4
# 9    2.4
# 13   2.4
# 14   2.3
# 31   2.3
# ..   ...
# 137  0.1
# 140  0.1
# 112  0.1
# 136  0.1
# 117  0.1
#
# [146 rows x 1 columns]

# %% [markdown]
# # Parte 2

# %%
df3 = pd.DataFrame({"Nombre":["Gael","Paola","Maria","Josue","Martha","Romero","Sandra"], "Edad":[27,28,29,28,30,30,28]})
df3
# Out:
#    Nombre  Edad
# 0    Gael    27
# 1   Paola    28
# 2   Maria    29
# 3   Josue    28
# 4  Martha    30
# 5  Romero    30
# 6  Sandra    28

# %%
df3 = df3.drop(3, axis=0) #Eliminar una fila por indice
df3.head()
# Out:
#    Nombre  Edad
# 0    Gael    27
# 1   Paola    28
# 2   Maria    29
# 4  Martha    30
# 5  Romero    30

# %%
np.NaN
# Out:
# nan

# %%
#Agregar una columna
df3["Residencia"] = ["Madrid","Madrid","Bilbao","Madrid","Madrid","Zaragoza","Sevilla"]
df3
# Out:
#    Nombre  Edad Residencia
# 0    Gael    27     Madrid
# 1   Paola    28     Madrid
# 2   Maria    29     Bilbao
# 3   Josue    28     Madrid
# 4  Martha    30     Madrid
# 5  Romero    30   Zaragoza
# 6  Sandra    28    Sevilla

# %%
#Agregar una fila 
df3 = df3.append({"Nombre":"Marco","Edad":27,"Residencia":"Bilbao"}, ignore_index=True)
df3
# Out:
#    Nombre  Edad Residencia
# 0    Gael    27     Madrid
# 1   Paola    28     Madrid
# 2   Maria    29     Bilbao
# 3   Josue    28     Madrid
# 4  Martha    30     Madrid
# 5  Romero    30   Zaragoza
# 6  Sandra    28    Sevilla
# 7   Marco    27     Bilbao
# 8   Marco    27     Bilbao

# %%
#Sustituir una fila
df3.iloc[-1]=["Julieta",29,"Sevilla"]
df3
# Out:
#     Nombre  Edad Residencia
# 0     Gael    27     Madrid
# 1    Paola    28     Madrid
# 2    Maria    29     Bilbao
# 3    Josue    28     Madrid
# 4   Martha    30     Madrid
# 5   Romero    30   Zaragoza
# 6   Sandra    28    Sevilla
# 7    Marco    27     Bilbao
# 8  Julieta    29    Sevilla

# %%
df3.iat[5,0]=[1,2,3]
df3
# Out:
#       Nombre  Edad Residencia
# 0       Gael    27     Madrid
# 1      Paola    28     Madrid
# 2      Maria    29     Bilbao
# 3      Josue    28     Madrid
# 4     Martha    30     Madrid
# 5  [1, 2, 3]    30   Zaragoza
# 6     Sandra    28    Sevilla
# 7      Marco    27     Bilbao
# 8    Julieta    29    Sevilla

# %%
df3.at[0:3,"Nacionalidad"]="Español" #Agregar una columna y Cambiar un valor
df3
# Out:
#       Nombre  Edad Residencia Nacionalidad
# 0       Gael    27     Madrid      Español
# 1      Paola    28     Madrid      Español
# 2      Maria    29     Bilbao      Español
# 3      Josue    28     Madrid      Español
# 4     Martha    30     Madrid          NaN
# 5  [1, 2, 3]    30   Zaragoza          NaN
# 6     Sandra    28    Sevilla          NaN
# 7      Marco    27     Bilbao          NaN
# 8    Julieta    29    Sevilla          NaN

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Nombre        9 non-null      object
#  1   Edad          9 non-null      int64
#  2   Residencia    9 non-null      object
#  3   Nacionalidad  4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 416.0+ bytes

# %%
del df3["Nacionalidad"]
df3
# Out:
#       Nombre  Edad Residencia
# 0       Gael    27     Madrid
# 1      Paola    28     Madrid
# 2      Maria    29     Bilbao
# 3      Josue    28     Madrid
# 4     Martha    30     Madrid
# 5  [1, 2, 3]    30   Zaragoza
# 6     Sandra    28    Sevilla
# 7      Marco    27     Bilbao
# 8    Julieta    29    Sevilla

# %%
df3
# Out:
#       Nombre  Edad Residencia
# 0       Gael    27     Madrid
# 1      Paola    28     Madrid
# 2      Maria    29     Bilbao
# 3      Josue    28     Madrid
# 4     Martha    30     Madrid
# 5  [1, 2, 3]    30   Zaragoza
# 6     Sandra    28    Sevilla
# 7      Marco    27     Bilbao
# 8    Julieta    29    Sevilla

# %%
df3["Edad"].value_counts() #Para contar el número de apariciones de cada elemento
# Out:
# 28    3
# 27    2
# 29    2
# 30    2
# Name: Edad, dtype: int64

# %%
df3["Residencia"].value_counts(normalize=False)
# Out:
# Madrid      4
# Bilbao      2
# Sevilla     2
# Zaragoza    1
# Name: Residencia, dtype: int64

# %%
df3["Residencia"].value_counts(normalize=True)
# Out:
# Madrid      0.444444
# Bilbao      0.222222
# Sevilla     0.222222
# Zaragoza    0.111111
# Name: Residencia, dtype: float64

# %%
df3["Edad"].unique() #Muestra los valores únicos de la columna
# Out:
# array([27, 28, 29, 30])

# %%
df3["Residencia"].unique()
# Out:
# array(['Madrid', 'Bilbao', 'Zaragoza', 'Sevilla'], dtype=object)

# %%
df3["Residencia"]
# Out:
# 0      Madrid
# 1      Madrid
# 2      Bilbao
# 3      Madrid
# 4      Madrid
# 5    Zaragoza
# 6     Sevilla
# 7      Bilbao
# 8     Sevilla
# Name: Residencia, dtype: object

# %%
df3.Residencia
# Out:
# 0      Madrid
# 1      Madrid
# 2      Bilbao
# 3      Madrid
# 4      Madrid
# 5    Zaragoza
# 6     Sevilla
# 7      Bilbao
# 8     Sevilla
# Name: Residencia, dtype: object

# %%
df3
# Out:
#     Nombre  Edad Residencia
# 0     Gael    27     Madrid
# 1    Paola    28     Madrid
# 2    Maria    29     Bilbao
# 3    Josue    28     Madrid
# 4   Martha    30     Madrid
# 5   Romero    30   Zaragoza
# 6   Sandra    28    Sevilla
# 7  Julieta    29    Sevilla
# 8    Marco    27     Bilbao

# %%
df3
# Out:
#       Nombre  Edad Residencia
# 0       Gael    27     Madrid
# 1      Paola    28     Madrid
# 2      Maria    29     Bilbao
# 3      Josue    28     Madrid
# 4     Martha    30     Madrid
# 5  [1, 2, 3]    30   Zaragoza
# 6     Sandra    28    Sevilla
# 7      Marco    27     Bilbao
# 8    Julieta    29    Sevilla

# %%
df3["Edad"]==28
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: Edad, dtype: bool

# %%
df3[df3["Edad"]==28]
# Out:
#    Nombre  Edad Residencia
# 1   Paola    28     Madrid
# 3   Josue    28     Madrid
# 6  Sandra    28    Sevilla

# %%
df3[df3["Edad"]<28]
# Out:
#   Nombre  Edad Residencia
# 0   Gael    27     Madrid
# 7  Marco    27     Bilbao

# %%
df3[df3.Edad<28]
# Out:
#   Nombre  Edad Residencia
# 0   Gael    27     Madrid
# 7  Marco    27     Bilbao

# %%
#Filtrar por mayores de 27
df3[df3["Edad"]>27]
# Out:
#       Nombre  Edad Residencia
# 1      Paola    28     Madrid
# 2      Maria    29     Bilbao
# 3      Josue    28     Madrid
# 4     Martha    30     Madrid
# 5  [1, 2, 3]    30   Zaragoza
# 6     Sandra    28    Sevilla
# 8    Julieta    29    Sevilla

# %%
df3.Residencia=="Madrid"
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# Name: Residencia, dtype: bool

# %%
df3[df3.Residencia=="Madrid"]
# Out:
#    Nombre  Edad Residencia
# 0    Gael    27     Madrid
# 1   Paola    28     Madrid
# 3   Josue    28     Madrid
# 4  Martha    30     Madrid

# %%
df_VivenMadrid = df3[df3.Residencia=="Madrid"]

# %%
df_VivenMadrid
# Out:
#    Nombre  Edad Residencia
# 0    Gael    27     Madrid
# 1   Paola    28     Madrid
# 3   Josue    28     Madrid
# 4  Martha    30     Madrid

# %%
#Filtrar por quienes viven en Madrid
df3[df3["Residencia"]=="Madrid"]
# Out:
#    Nombre  Edad Residencia
# 0    Gael    27     Madrid
# 1   Paola    28     Madrid
# 3   Josue    28     Madrid
# 4  Martha    30     Madrid

# %%
(df3["Edad"]<29)&(df3["Residencia"]=="Madrid")
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
#Filtrar por quienes viven en Madrid y tienen menos de 29 años
df3[(df3["Edad"]<29)&(df3["Residencia"]=="Madrid")]
# Out:
#   Nombre  Edad Residencia
# 0   Gael    27     Madrid
# 1  Paola    28     Madrid
# 3  Josue    28     Madrid

# %%
df3.Edad.values
# Out:
# array([27, 28, 29, 28, 30, 30, 28, 27, 29])

# %%
df3.Residencia.unique()
# Out:
# array(['Madrid', 'Bilbao', 'Zaragoza', 'Sevilla'], dtype=object)

# %%
df6 = df3[df3["Residencia"]=="Madrid"]
df6["Nombre"].values
# Out:
# array(['Gael', 'Paola', 'Josue', 'Martha'], dtype=object)

# %%
#Obtener los nombres por residencia 
for i in df3.Residencia.unique():
    print(i,":")
    print(df3[df3["Residencia"]==i]["Nombre"].values)
    print("**_______**")
# Out:
# Madrid :
# ['Gael' 'Paola' 'Josue' 'Martha']
# **_______**
# Bilbao :
# ['Maria' 'Marco']
# **_______**
# Zaragoza :
# [list([1, 2, 3])]
# **_______**
# Sevilla :
# ['Sandra' 'Julieta']
# **_______**

# %%
df3[(df3["Edad"]<29) | (df3["Residencia"]=="Madrid")]
# Out:
#    Nombre  Edad Residencia
# 0    Gael    27     Madrid
# 1   Paola    28     Madrid
# 3   Josue    28     Madrid
# 4  Martha    30     Madrid
# 6  Sandra    28    Sevilla
# 7   Marco    27     Bilbao

# %%
df5 = df3[(df3["Edad"]<29)&(df3["Residencia"]=="Madrid")]
df5
# Out:
#   Nombre  Edad Residencia
# 0   Gael    27     Madrid
# 1  Paola    28     Madrid
# 3  Josue    28     Madrid

# %%
df5["Nombre"].values
# Out:
# array(['Gael', 'Paola', 'Josue'], dtype=object)

# %%
df5["Nombre"].index
# Out:
# Int64Index([0, 1, 3], dtype='int64')

# %%
df3
# Out:
#     Nombre  Edad Residencia
# 0     Gael    27     Madrid
# 1    Paola    28     Madrid
# 2    Maria    29     Bilbao
# 3    Josue    28     Madrid
# 4   Martha    30     Madrid
# 5   Romero    30   Zaragoza
# 6   Sandra    28    Sevilla
# 7  Julieta    29    Sevilla
# 8    Marco    27     Bilbao

# %%
x = df3[(df3["Edad"]<29)&(df3["Residencia"]=="Madrid")][["Nombre","Edad"]].sort_values("Edad").reset_index(drop=True).head(1)
x
# Out:
#   Nombre  Edad
# 0   Gael    27

# %%
df100 = df3[(df3["Edad"]<29)&(df3["Residencia"]=="Madrid")]
df100
# Out:
#   Nombre  Edad Residencia
# 0   Gael    27     Madrid
# 1  Paola    28     Madrid
# 3  Josue    28     Madrid

# %%
df101 = df100[["Nombre","Edad"]]
df101
# Out:
#   Nombre  Edad
# 0   Gael    27
# 1  Paola    28
# 3  Josue    28

# %%
df102 = df101.sort_values("Edad")
df102
# Out:
#   Nombre  Edad
# 0   Gael    27
# 1  Paola    28
# 3  Josue    28

# %%
df102.reset_index(inplace=True)

# %%
x = df102.head(1)
x
# Out:
#    index Nombre  Edad
# 0      0   Gael    27

# %%
#Obtener una lista con los nombes de quienes viven en Madrid y tienen menos de 29 años 
list(df3[(df3["Edad"]<29)&(df3["Residencia"]=="Madrid")]["Nombre"])
# Out:
# ['Gael', 'Paola', 'Josue']

# %%
np.nan
# Out:
# nan
